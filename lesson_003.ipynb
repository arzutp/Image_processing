# %%
import os
os.getcwd()
os.listdir()
# Out:
# ['.ipynb_checkpoints', '2.png', '3.jpg', '4.jpg', '5.jpg', 'lesson_003.ipynb']

# %%
path = os.getcwd()
jpg_files = [f for f in os.listdir(path) if f.endswith('.jpg')]
jpg_files
# Out:
# ['3.jpg', '4.jpg', '5.jpg']

# %%
import numpy as np
import matplotlib.pyplot as plt
img1 = plt.imread(jpg_files[2])
plt.imshow(img1)
plt.show()

# %%
def get_value_from_triple(temp):
    return int(temp[0]/3 + temp[1]/3 + temp[2]/3)

get_value_from_triple(img1[50,50,:])
# Out:
# 248

# %%
def get_01_from_triple(temp1):
    temp = int(temp1[0]/3+temp1[1]/3+temp1[2]/3)
    if temp<110:
        return 0
    else:
        return 1
get_01_from_triple(img1[50,50,:])
# Out:
# 1

# %%
mean1 = img1[10,10,0]/3+img1[10,10,1]/3+img1[10,10,2]/3
mean1
# Out:
# 241.33333333333334

# %%
def convert_rgb_to_bw(img1):
    m,n,k = img1.shape
    new_image = np.zeros((m,n),dtype='uint8')
    for i in range(m):
        for j in range(n):
            s = get_01_from_triple(img1[i,j,:])
            new_image[i,j] = s
    return new_image

# %%
def convert_rgb_to_gray(im_1):
    m,n,k = im_1.shape
    new_img = np.zeros((m,n),dtype = 'uint8')
    for i in range(m):
        for j in range(n):
            s = get_value_from_triple(im_1[i,j,:])            
            new_img[i,j] = s    
    return new_img

# %%
img1 = plt.imread(jpg_files[2])
img1_gray = convert_rgb_to_gray(img1)
img1_bw = convert_rgb_to_bw(img1)

# %%
plt.subplot(1,3,1)
plt.imshow(img1)
plt.show()

# %%
plt.subplot(1,3,1)
plt.imshow(img1_gray,cmap='gray')
plt.show()

# %%
plt.subplot(1,3,1)
plt.imshow(img_bw,cmap='gray')
plt.show()
